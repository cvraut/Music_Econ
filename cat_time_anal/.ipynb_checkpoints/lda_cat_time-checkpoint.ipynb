# %%
import pickle
import pandas as pd
import numpy as np
from collections import Counter,defaultdict
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(15,10)})
from time import time

# %%
song_2_cat = pickle.load(open("../dataClustering/song_art_2_lda_cat_prop","rb"))
song_2_cat
# Out:
#                                                     song  \
# 0                                            sauce it up
# 1                                          backroad song
# 2                                      feelin' satisfied
# 3                             saturday morning confusion
# 4                                            country man
# 5                                                    try
# 6                                           big in japan
# 7                               cheeseburger in paradise
# 8                                              landslide
# 9                                 some enchanted evening
# 10            when you're in love with a beautiful woman
# 11                                              blackout
# 12                                               push it
# 13                                           best friend
# 14                                      so good together
# 15                                        all night long
# 16                                          pretty girls
# 17                                          one way love
# 18                                        baby i'm yours
# 19                                             say maybe
# 20                     take it slow (out in the country)
# 21                                      christmas lights
# 22                                                d.o.a.
# 23                                    prove it all night
# 24                                                  work
# 25                                             hey! baby
# 26                                         love or leave
# 27                              stay with me (brass bed)
# 28                                          and get away
# 29                              the greatest love of all
# ...                                                  ...
# 22635                                           cinnamon
# 22636           i could never take the place of your man
# 22637                                  young school girl
# 22638                                 i'm gonna miss you
# 22639                                  it goes like this
# 22640                                     you're no good
# 22641                                       mind blowin'
# 22642                                      turn to stone
# 22643                                          riverboat
# 22644  rock n' roll (i gave you the best years of my ...
# 22645                                            amazing
# 22646                           no one for me to turn to
# 22647                                  you are not alone
# 22648                       that's how strong my love is
# 22649                                         whatta man
# 22650                                         this is me
# 22651                                  come softly to me
# 22652                                       train, train
# 22653                                      the wild life
# 22654                                    to each his own
# 22655                                             margie
# 22656                                    spin that wheel
# 22657                                easy for you to say
# 22658                                  our day will come
# 22659                                          one voice
# 22660                                      achy breaky 2
# 22661                               why i sing the blues
# 22662                                           with you
# 22663                              play that funky music
# 22664                             god, your mama, and me
#
#                                                artist     cat_0     cat_1  \
# 0                                        lil uzi vert  0.000000  0.102696
# 1                                       granger smith  0.639467  0.178155
# 2                                              boston  0.473315  0.073715
# 3                                       bobby russell  0.083360  0.424313
# 4                                          luke bryan  0.025522  0.414117
# 5                                                p!nk  0.000000  0.000000
# 6                                          alphaville  0.000000  0.290520
# 7                                       jimmy buffett  0.000000  0.306976
# 8                                  olivia newton-john  0.019634  0.056153
# 9                                         jane olivor  0.000000  0.000000
# 10                                           dr. hook  0.055709  0.000000
# 11                                   breathe carolina  0.075560  0.058467
# 12                                            garbage  0.115100  0.000000
# 13                                             brandy  0.000000  0.000000
# 14                                           andy kim  0.000000  0.000000
# 15                                       sandy nelson  0.100000  0.000000
# 16                       britney spears & iggy azalea  0.118346  0.101110
# 17                                                tka  0.000000  0.000000
# 18                                               shai  0.000000  0.000000
# 19                                       neil diamond  0.000000  0.000000
# 20                                         lighthouse  0.016766  0.409469
# 21                                           coldplay  0.000000  0.072094
# 22                                          bloodrock  0.000000  0.000000
# 23                                  bruce springsteen  0.000000  0.086797
# 24                            rihanna featuring drake  0.351261  0.201751
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22655  0.591861  0.143546  0.248060  0.000000  0.000000  0.000000  0.000000
# 22656  0.028766  0.000000  0.000000  0.000000  0.188234  0.317113  0.000000
# 22657  0.110158  0.832299  0.000000  0.000000  0.000000  0.000000  0.000000
# 22658  0.677935  0.000000  0.000000  0.092041  0.000000  0.000000  0.000000
# 22659  0.000000  0.219389  0.000000  0.000000  0.000000  0.000000  0.000000
# 22660  0.050691  0.532667  0.000000  0.000000  0.065081  0.156116  0.017111
# 22661  0.000000  0.303724  0.000000  0.000000  0.075388  0.015005  0.000000
# 22662  0.197938  0.045316  0.003429  0.066468  0.286836  0.000000  0.000000
# 22663  0.000000  0.030292  0.135822  0.000000  0.040604  0.253029  0.000000
# 22664  0.254597  0.071115  0.057013  0.135886  0.000000  0.000000  0.000000
#
#           cat_9    cat_10
# 0      0.143395  0.000000
# 1      0.000000  0.077883
# 2      0.000000  0.000000
# 3      0.000000  0.331200
# 4      0.117062  0.106683
# 5      0.000000  0.000000
# 6      0.025096  0.306833
# 7      0.000000  0.326648
# 8      0.000000  0.405867
# 9      0.000000  0.387055
# 10     0.000000  0.000000
# 11     0.000000  0.000000
# 12     0.000000  0.000000
# 13     0.000000  0.000000
# 14     0.061477  0.000000
# 15     0.209286  0.000000
# 16     0.035254  0.054311
# 17     0.000000  0.035579
# 18     0.000000  0.000000
# 19     0.017718  0.000000
# 20     0.005227  0.221679
# 21     0.050173  0.404725
# 22     0.000000  0.477868
# 23     0.000000  0.098111
# 24     0.036873  0.000000
# 25     0.120290  0.000000
# 26     0.077626  0.000000
# 27     0.000000  0.293350
# 28     0.126068  0.137217
# 29     0.000000  0.369342
# ...         ...       ...
# 22635  0.082550  0.000000
# 22636  0.106976  0.000000
# 22637  0.000000  0.000000
# 22638  0.050897  0.000000
# 22639  0.154460  0.000000
# 22640  0.100213  0.000000
# 22641  0.154697  0.000000
# 22642  0.000000  0.522586
# 22643  0.000000  0.000000
# 22644  0.000000  0.143868
# 22645  0.058873  0.000000
# 22646  0.000000  0.094698
# 22647  0.000000  0.091672
# 22648  0.000000  0.183001
# 22649  0.042439  0.021237
# 22650  0.000000  0.069885
# 22651  0.000000  0.000000
# 22652  0.049815  0.000000
# 22653  0.034804  0.090903
# 22654  0.000000  0.289431
# 22655  0.000000  0.000000
# 22656  0.000000  0.000000
# 22657  0.000000  0.013099
# 22658  0.000000  0.215572
# 22659  0.000000  0.553894
# 22660  0.000000  0.000000
# 22661  0.061080  0.016731
# 22662  0.178461  0.215560
# 22663  0.006893  0.008565
# 22664  0.000000  0.276120
#
# [22665 rows x 13 columns]

# %%
dom_cats = []
for i,r in song_2_cat.iterrows():
    prop_2_cat = sorted([(p,i) for i,p in enumerate(r[2:]) if p > 0.0],reverse=True)
    dom_cats.append([c for p,c in prop_2_cat[:3]])
song_2_cat["3Dom_Cat"] = dom_cats
song_2_cat.head()
# Out:
#                          song         artist     cat_0     cat_1     cat_2  \
# 0                 sauce it up   lil uzi vert  0.000000  0.102696  0.038709
# 1               backroad song  granger smith  0.639467  0.178155  0.000000
# 2           feelin' satisfied         boston  0.473315  0.073715  0.110953
# 3  saturday morning confusion  bobby russell  0.083360  0.424313  0.000000
# 4                 country man     luke bryan  0.025522  0.414117  0.049054
#
#       cat_3     cat_4     cat_5     cat_6     cat_7  cat_8     cat_9  \
# 0  0.079205  0.019801  0.000000  0.000000  0.609886    0.0  0.143395
# 1  0.000000  0.027369  0.000000  0.074016  0.000000    0.0  0.000000
# 2  0.000000  0.000000  0.131726  0.205465  0.000000    0.0  0.000000
# 3  0.000000  0.018672  0.000000  0.025331  0.109812    0.0  0.000000
# 4  0.000000  0.059638  0.000000  0.087279  0.138261    0.0  0.117062
#
#      cat_10    3Dom_Cat
# 0  0.000000   [7, 9, 1]
# 1  0.077883  [0, 1, 10]
# 2  0.000000   [0, 6, 5]
# 3  0.331200  [1, 10, 7]
# 4  0.106683   [1, 7, 9]

# %%
BB = pd.read_csv("../data/Hot Stuff.csv")
low = lambda s: s.lower()
BB["song"] = [s.lower() for s in BB["Song"]]
BB["artist"] = [s.lower() for s in BB["Performer"]]
BB["timestep"] = pd.to_datetime(BB["WeekID"])
BB = BB.sort_values("timestep")
BB.head()
# Out:
#                                                      url    WeekID  \
# 5037   http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 10546  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 3986   http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 13350  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
# 68116  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958
#
#        Week Position                  Song          Performer  \
# 5037              48          Return To Me        Dean Martin
# 10546             70         Don't Go Home      The Playmates
# 3986               8          My True Love         Jack Scott
# 13350             41  Early In The Morning        Buddy Holly
# 68116             90                  Stay  The Ames Brothers
#
#                                 SongID  Instance  Previous Week Position  \
# 5037           Return To MeDean Martin         1                     NaN
# 10546       Don't Go HomeThe Playmates         1                     NaN
# 3986            My True LoveJack Scott         1                     NaN
# 13350  Early In The MorningBuddy Holly         1                     NaN
# 68116            StayThe Ames Brothers         1                     NaN
#
#        Peak Position  Weeks on Chart                  song             artist  \
# 5037              48               1          return to me        dean martin
# 10546             70               1         don't go home      the playmates
# 3986               8               1          my true love         jack scott
# 13350             41               1  early in the morning        buddy holly
# 68116             90               1                  stay  the ames brothers
#
#         timestep
# 5037  1958-08-02
# 10546 1958-08-02
# 3986  1958-08-02
# 13350 1958-08-02
# 68116 1958-08-02

# %%
total_cat_participation = [np.sum(r[2:-1]) for i,r in song_2_cat.iterrows()]

# %%
sns.distplot(total_cat_participation) # see total category participation of each song

# %%
sorted(total_cat_participation)[:10]
# Out:
# [0.9090790748596191,
#  0.9242226481437683,
#  0.9338707774877548,
#  0.9350286722183228,
#  0.9370019733905792,
#  0.9380447417497635,
#  0.9393652230501175,
#  0.9401944279670715,
#  0.9465197920799255,
#  0.9510214924812317]

# %% [markdown]
# Songs appear to be in categories, there are no songs that are left out

# %%
max_cat_participation = [max(r[2:-1]) for i,r in song_2_cat.iterrows()]

# %%
sns.distplot(max_cat_participation) # most songs have a category preference(s)

# %%
Big_DF = BB.merge(song_2_cat,left_on=["song","artist"],right_on=["song","artist"],how="inner")
print(len(Big_DF))
print(len(BB))
Big_DF.head()
# Out:
# 275902
# 315295
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1958-0...   8/2/1958
# 1  http://www.billboard.com/charts/hot-100/1958-0...   8/9/1958
# 2  http://www.billboard.com/charts/hot-100/1958-0...  8/16/1958
# 3  http://www.billboard.com/charts/hot-100/1958-0...  8/23/1958
# 4  http://www.billboard.com/charts/hot-100/1958-0...   8/2/1958
#
#    Week Position           Song      Performer                      SongID  \
# 0             48   Return To Me    Dean Martin     Return To MeDean Martin
# 1             63   Return To Me    Dean Martin     Return To MeDean Martin
# 2             92   Return To Me    Dean Martin     Return To MeDean Martin
# 3             96   Return To Me    Dean Martin     Return To MeDean Martin
# 4             70  Don't Go Home  The Playmates  Don't Go HomeThe Playmates
#
#    Instance  Previous Week Position  Peak Position  Weeks on Chart  ...  \
# 0         1                     NaN             48               1  ...
# 1         1                    48.0             48               2  ...
# 2         1                    63.0             48               3  ...
# 3         1                    92.0             48               4  ...
# 4         1                     NaN             70               1  ...
#
#       cat_2     cat_3     cat_4  cat_5  cat_6  cat_7     cat_8  cat_9  cat_10  \
# 0  0.513289  0.000000  0.000000    0.0    0.0    0.0  0.235095    0.0     0.0
# 1  0.513289  0.000000  0.000000    0.0    0.0    0.0  0.235095    0.0     0.0
# 2  0.513289  0.000000  0.000000    0.0    0.0    0.0  0.235095    0.0     0.0
# 3  0.513289  0.000000  0.000000    0.0    0.0    0.0  0.235095    0.0     0.0
# 4  0.429937  0.103237  0.129957    0.0    0.0    0.0  0.000000    0.0     0.0
#
#     3Dom_Cat
# 0  [2, 1, 8]
# 1  [2, 1, 8]
# 2  [2, 1, 8]
# 3  [2, 1, 8]
# 4  [2, 0, 1]
#
# [5 rows x 25 columns]

# %%
for col in song_2_cat.columns[2:-1]:
    sns.distplot(song_2_cat[song_2_cat[col]>0.0][col])
plt.show()

# %%
len(Big_DF.timestep.unique())
# Out:
# 3153

# %%
week_data = []
week_data_colnames = ["timestep"]+["cat{}_cnts".format(i) for i in range(11)]+["cat{}_sums".format(i) for i in range(11)]+["cat{}_avg".format(i) for i in range(11)]
for week in Big_DF.timestep.unique():
    subset_df = Big_DF[Big_DF["timestep"] == week]
    cat_cnts = [0]*11
    cat_sums = [0.0]*11
    for i,r in subset_df.iterrows():
        for cat in r["3Dom_Cat"]:
            cat_cnts[cat]+=1
            cat_sums[cat]+=r["cat_{}".format(cat)]
    cat_avg = [(s/c) if c > 0 else 0 for s,c in zip(cat_sums,cat_cnts)]
    week_data.append([week]+cat_cnts+cat_sums+cat_avg)

# %%
week_data_df = pd.DataFrame(week_data,columns=week_data_colnames)
print(week_data_df.shape)
week_data_df.head()
# Out:
# (3153, 34)
#     timestep  cat0_cnts  cat1_cnts  cat2_cnts  cat3_cnts  cat4_cnts  \
# 0 1958-08-02         17         25         49         23         15
# 1 1958-08-09         18         25         53         28         14
# 2 1958-08-16         14         22         46         24         15
# 3 1958-08-23         17         22         46         23         14
# 4 1958-08-30         16         18         41         23         13
#
#    cat5_cnts  cat6_cnts  cat7_cnts  cat8_cnts  ...  cat1_avg  cat2_avg  \
# 0         11         19          3          3  ...  0.269514  0.455901
# 1         13         18          4          3  ...  0.272524  0.451417
# 2         11         15          4          3  ...  0.283769  0.455144
# 3         12         14          5          3  ...  0.280207  0.445662
# 4         11         13          5          2  ...  0.313165  0.456953
#
#    cat3_avg  cat4_avg  cat5_avg  cat6_avg  cat7_avg  cat8_avg  cat9_avg  \
# 0  0.326027  0.229547  0.206242  0.231762  0.228968  0.191738  0.242538
# 1  0.321185  0.209374  0.183920  0.229945  0.320396  0.191738  0.240827
# 2  0.291122  0.205967  0.206762  0.246427  0.233494  0.191738  0.250288
# 3  0.314947  0.202642  0.200878  0.247508  0.305731  0.191738  0.250288
# 4  0.315376  0.192908  0.201776  0.252156  0.234258  0.170060  0.242846
#
#    cat10_avg
# 0   0.285916
# 1   0.286398
# 2   0.294703
# 3   0.292283
# 4   0.283094
#
# [5 rows x 34 columns]

# %%
week_data_df = week_data_df.sort_values("timestep")

# %%
for i in range(11):
    sns.lineplot(x=week_data_df["timestep"],y=week_data_df["cat{}_avg".format(i)])
    plt.show()
    plt.clf()

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt

for i in range(11):
    x = week_data_df["timestep"]
    y = week_data_df["cat{}_avg".format(i)]
    model = SimpleExpSmoothing(np.asarray(y))
    #model._index = x

    fit1 = model.fit()
    #pred1 = fit1.forecast(9)
    fit2 = model.fit(smoothing_level=.4)
    #pred2 = fit2.forecast(9)
    fit3 = model.fit(smoothing_level=.2)
    #pred3 = fit3.forecast(9)

    plt.figure(figsize=(10, 5))
    plt.plot(x[:100], fit1.fittedvalues[:100], label = "Original", alpha=0.8)
    plt.plot(x[:100], fit2.fittedvalues[:100], label = "fit2", alpha=0.8)
    plt.plot(x[:100], fit3.fittedvalues[:100], label = "fit3", alpha=0.8)
    plt.legend(fontsize=14)
    plt.show()
    plt.clf()

# %%
tmp = week_data_df.reset_index().drop("index",axis=1)

# %%
tmp.head()
# Out:
#     timestep  cat0_cnts  cat1_cnts  cat2_cnts  cat3_cnts  cat4_cnts  \
# 0 1958-08-02         17         25         49         23         15
# 1 1958-08-09         18         25         53         28         14
# 2 1958-08-16         14         22         46         24         15
# 3 1958-08-23         17         22         46         23         14
# 4 1958-08-30         16         18         41         23         13
#
#    cat5_cnts  cat6_cnts  cat7_cnts  cat8_cnts  ...  cat1_avg  cat2_avg  \
# 0         11         19          3          3  ...  0.269514  0.455901
# 1         13         18          4          3  ...  0.272524  0.451417
# 2         11         15          4          3  ...  0.283769  0.455144
# 3         12         14          5          3  ...  0.280207  0.445662
# 4         11         13          5          2  ...  0.313165  0.456953
#
#    cat3_avg  cat4_avg  cat5_avg  cat6_avg  cat7_avg  cat8_avg  cat9_avg  \
# 0  0.326027  0.229547  0.206242  0.231762  0.228968  0.191738  0.242538
# 1  0.321185  0.209374  0.183920  0.229945  0.320396  0.191738  0.240827
# 2  0.291122  0.205967  0.206762  0.246427  0.233494  0.191738  0.250288
# 3  0.314947  0.202642  0.200878  0.247508  0.305731  0.191738  0.250288
# 4  0.315376  0.192908  0.201776  0.252156  0.234258  0.170060  0.242846
#
#    cat10_avg
# 0   0.285916
# 1   0.286398
# 2   0.294703
# 3   0.292283
# 4   0.283094
#
# [5 rows x 34 columns]

# %%
pickle.dump(tmp,open("../data/lda_clusters_week_2_cluster_info.pickle","wb"))

# %%
lolo = BB.groupby("timestep").size().reset_index(name="cnts")
sns.lineplot(x=lolo["timestep"],y=lolo["cnts"],color="green",label="songs listed by BB")
lolo2 = Big_DF.groupby("timestep").size().reset_index(name="cnts")
ax=sns.lineplot(x=lolo2["timestep"],y=lolo2["cnts"],label="lyric data retrieved")
ax.set_title("Weekly Representation of Acquired Data")
ax.set_ylim(0,105)
# Out:
# (0, 105)

# %%
# Out:
#        timestep  cnts
# 0    1958-08-02   100
# 1    1958-08-09   100
# 2    1958-08-16   100
# 3    1958-08-23   100
# 4    1958-08-30   100
# 5    1958-09-06   100
# 6    1958-09-13   100
# 7    1958-09-20   100
# 8    1958-09-27   100
# 9    1958-10-04   100
# 10   1958-10-11   100
# 11   1958-10-18   100
# 12   1958-10-25   100
# 13   1958-11-01   100
# 14   1958-11-08   100
# 15   1958-11-15   100
# 16   1958-11-22   100
# 17   1958-11-29   100
# 18   1958-12-06   100
# 19   1958-12-13   100
# 20   1958-12-20   100
# 21   1958-12-27   100
# 22   1959-01-03   100
# 23   1959-01-10   100
# 24   1959-01-17   100
# 25   1959-01-24   100
# 26   1959-01-31   100
# 27   1959-02-07   100
# 28   1959-02-14   100
# 29   1959-02-21   100
# ...         ...   ...
# 3123 2018-06-09   100
# 3124 2018-06-16   100
# 3125 2018-06-23   100
# 3126 2018-06-30   100
# 3127 2018-07-07   100
# 3128 2018-07-14   100
# 3129 2018-07-21   100
# 3130 2018-07-28   100
# 3131 2018-08-04   100
# 3132 2018-08-11   100
# 3133 2018-08-18   100
# 3134 2018-08-25   100
# 3135 2018-09-01   100
# 3136 2018-09-08   100
# 3137 2018-09-15   100
# 3138 2018-09-22   100
# 3139 2018-09-29   100
# 3140 2018-10-06   100
# 3141 2018-10-13   100
# 3142 2018-10-20   100
# 3143 2018-10-27   100
# 3144 2018-11-03   100
# 3145 2018-11-10   100
# 3146 2018-11-17   100
# 3147 2018-11-24   100
# 3148 2018-12-01   100
# 3149 2018-12-08   100
# 3150 2018-12-15   100
# 3151 2018-12-22   100
# 3152 2018-12-29   100
#
# [3153 rows x 2 columns]
